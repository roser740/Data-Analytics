# %% [markdown]
# # **Nivell 1**

# %% [markdown]
# # **Exercici 1: Selecció de Personal**

# %% [markdown]
# Tu treballes com a analista de dades en el departament de RRHH d'una empresa. S'ha obert una nova oferta laboral interna i l'empresa ha decidit que només les primeres 10 persones que s'inscriguin podran participar en el procés de selecció.

# %% [markdown]
# Per això, t'han encarregat desenvolupar una eina senzilla en Python que actuï com a formulari d'inscripció i sistema de classificació inicial. Aquest formulari ha de permetre introduir, per a cada candidat/a:
#
#
# *   Nom i Cognoms
# *   Telèfon de contacte
# *   Anys d'experiència dins de l'empresa
# *   Coneixement de Català (0–3 punts)
#     *   0 = sense coneixement
#     *   1 = fins a nivell B1
#     *   2 = nivell B2
#     *   3 = C1 o superior
# *   Domini d'Excel (0-3 punts)
#     *   0 = nivell bàsic
#     *   1 = ús de funcions
#     *   2 = taules dinàmiques
#     *   3 = Visual Basic i Macros
# *   Títol acadèmic (0-3 punts)
#     *   0 = ESO
#     *   1 = FP
#     *   2 = Universitat
#     *   3 = Màster o superior

# %% [markdown]
# Assegurant-se que tota la informació introduïda és correcta i entra dins els valors permesos. A partir d'aquestes dades, el programa haurà de calcular una puntuació total aplicant el pes de l'experiència (anys * 1.5) i sumant-hi els punts de català, excel i titulació, i a continuació classificar automàticament cada persona segons els llindars establerts per l'empresa:
#
# *   Prioritat Alta → puntuació ≥ 12
# *   Candidat adequat → 8 ≤ puntuació < 12
# *   No prioritari → puntuació < 8

# %% [markdown]
# Cada vegada que algú completa el formulari, s'ha de mostrar la seva puntuació individual. Quan ja s'hagin inscrit exactament deu persones, l'eina ha de deixar d'acceptar nous registres i generar un informe final en pantalla, ordenat primer segons la prioritat i, en cas d'empat, per la puntuació obtinguda. Aquest informe ha d'incloure el nom, el telèfon i la puntuació de cada candidat per tal que el departament de RRHH els pugui contactar ràpidament.

# %% [markdown]
# Per resoldre aquest exercici, hauràs de:
#
# » Desenvolupar un sistema modular amb les funcions següents:
# *   obtenir_dades
# *   validar_dades
# *   calcular_puntuacio
# *   classificar_candidat
# *   mostrar_individual
# *   mostrar_informe
# *   main_seleccio # orquestra totes les funcions
#
# » Escriure primer l'algoritme pas a pas, indicant clarament quines operacions farà cada funció.
# » Escriure el codi de cada funció.

# %% [markdown]
# # **Resultat**

# %% [markdown]
# ## 🧠 **Algoritme inicial**
#
# 1. Per cada usuari:
#     *   Demanar dades a l'usuari via input.
#     *   Validar que les dades estiguin dins els rangs.
#     *   Calcular la puntuació.
#     *   Classificar el candidat.
#     *   Mostrar la puntuació individual.
# 2. Mostrar informe final.

# %% [markdown]
# ## 🧩 **Descomponent el problema: naixement de les funcions**

# %% [markdown]
# ### ***✔ obtenir_dades()***
#
# Per emmagatzemar la informació de cada candidat utilitzarem un diccionari que contindrà totes les seves dades.
#
# **Tasques:**
# 1. Demanar les dades al candidat via input i guardar-les al diccionari amb la clau corresponent (nom, telèfon, antiguitat, català, excel i títol)
# 2. Retornar diccionari amb totes les dades d'un candidat.

# %%
def obtenir_dades():
    #inicialitzem el diccionari
    dades = {}
    #capturem les dades en format string i les guardem al diccionari
    dades['nom'] = input("Introdueix el teu nom i cognoms: ")
    dades['telèfon'] = input("Introdueix el telèfon: ")
    dades['antiguitat'] = input("Introdueix els anys d'experiència a l'empresa: ")
    dades['català'] = input("Introdueix el nivell de coneixement de català: ")
    dades['excel'] = input("Introdueix el nivell de coneixement d'excel: ")
    dades['títol'] = input("Introdueix el tipus de títol acadèmic: ")
    #retornem el diccionari amb les dades del candidat
    return dades

# %% [markdown]
# ### ***✔ validar_dades(dades)***
#
# **Paràmetre:** diccionari amb les dades d'un candidat.
#
# **Tasques:**
# 1. Processar les dades entrades:
#     - **Convertir** els camps numèrics a enters (antiguitat, català, excel i títol).
#     - **Validar** que els camps numèrics anteriors estiguin dins del rang permès.
#
# 2. Si falla algun procés mostra missatge d'error i retorna **False**.
#
# 3. Si no hi ha errors retorna **True**.

# %%
def validar_dades(dades):
    try:
        # Convertim els camps numèrics a tipus enter.
        dades['antiguitat'] = int(dades['antiguitat'])
        dades['català'] = int(dades['català'])
        dades['excel'] = int(dades['excel'])
        dades['títol'] = int(dades['títol'])

        # Validem els rangs de les dades numèriques. Si no estan dins del rang permès mostrem missatge i retornem False.
        if not (0 <= dades['català'] <= 3):
            print("Error: El coneixement de català ha de ser entre 0 i 3.")
            return False
        if not (0 <= dades['excel'] <= 3):
            print("Error: El domini d'Excel ha de ser entre 0 i 3.")
            return False
        if not (0 <= dades['títol'] <= 3):
            print("Error: El títol acadèmic ha de ser entre 0 i 3.")
            return False
        if dades['antiguitat'] < 0:
            print("Error: Els anys d'experiència no poden ser negatius.")
            return False

    #si la conversió dona error mostrem missatge i retornem False
    except ValueError:
        print("Error: Els camps numèrics (antiguitat, català, excel, títol) han de ser nombres enters.")
        return False

    #si no hi ha cap error retornem True
    return True

# %% [markdown]
# ### ***✔ Calcular_puntuació(dades)***
#
# **Paràmetre:** diccionari amb les dades d'un candidat.
#
# **Tasques:**
# 1. Calcular la puntuació: català + excel + títol + anys * 1,5
# 2. Retornar el resultat

# %%
def calcular_puntuació(dades):
    #calculem la puntuació
    puntuació = dades['català'] + dades['excel'] + dades['títol'] + dades['antiguitat'] * 1.5
    #retornem el resultat
    return puntuació

# %% [markdown]
# ### ***✔ classificar_candidat(puntuació)***
#
# **Paràmetre:** valor de la puntuació del candidat.
#
# **Tasques:**
# 1. Classificar el candidat segons barem:
#     *   si puntuació >= 12 --> prioritat alta
#     *   si puntuació < 8 --> no prioritari
#     *   en els altres casos (8<= puntuació <12) --> candidat adequat
# 2. Retornar resultat

# %%
def classificar_candidat(puntuació):
    #classifiquem el candidat en funció del valor de la puntuació
    if puntuació >= 12:
        classificació = "Prioritat alta"
    elif puntuació < 8:
        classificació = "No prioritari"
    else:
        classificació = "Candidat adequat"

    #retornem el resultat de la classificació
    return classificació

# %% [markdown]
# ### ***✔ mostrar_individual(puntuació)***
#
# **Paràmetre:** valor de la puntuació del candidat.
#
# **Tasques:**
# 1. Imprimir en pantalla "La teva puntuació és: x"

# %%
def mostrar_individual(puntuació):
    print(f"La teva puntuació és {puntuació}")

# %% [markdown]
# ### ***✔ mostrar_informe(llista)***
#
# **Paràmetre:** llista de diccionaris amb les dades de cada candidat.
#
# **Tasques:**
# 1. Ordenar la llista de candidats per puntuació.
# 2. Mostrar per pantalla els camps nom, telèfon i puntuació de la llista de candidats.
#
# **Observació:**
# L'enunciat ens demana ordenar primer per prioritat i després per puntuació. Observem que si ordenem només per puntuació també queda ordenat per prioritat.

# %%
def mostrar_informe(llista):
    print(f"Llista de candidats:")
    #ordenem la llista de candidats segons puntuació
    llista.sort(key=lambda x: -x['puntuació'])
    #per cada element de la llista ordenada de candidats mostrem nom, telèfon i puntuació
    for i in range(len(llista)):
        print(llista[i]['nom'],'tf:',llista[i]['telèfon'],'punts:',llista[i]['puntuació'])

# %% [markdown]
# ## 🧠 **Algoritme principal**
#
# Per emmagatzemar la informació de tots els candidats, utilitzarem una **llista de diccionaris**. Cada diccionari representarà un candidat individual i contindrà totes les seves dades, inclosa la puntuació calculada (`puntuació`) i la seva classificació (`classificació`).
#
# Aquesta estructura és ideal perquè:
# - Permet afegir fàcilment nous candidats a la llista.
# - Facilita l'accés a les dades de cada candidat per a la classificació i l'ordenació posterior.
#
# ### ***✔ main_seleccio():***
#
# 1. Mentre num usuaris <= 10:
#     *   Demanar dades a l'usuari via input: `obtenir_dades()`
#     *   Validar que les dades estiguin dins els rangs: `validar_dades()`
#     *   Si la validació és correcta:
#         *   Calcular puntuació: `calcular_puntuacio()`
#         *   Classificar el candidat: `classificar_candidat()`
#         *   Mostrar la puntuació individual: `mostrar_individual()`
# 2. Mostrar informe final: `mostrar_informe()`

# %%
def main_seleccio():
    #inicialitzem la llista de diccionaris on guardarem les dades de tots els candidats.
    candidats_registrats = []
    i = 1
    while i <= 10:
        #inicialitzem el diccionari on guardarem les dades del candidat que està entrant la informació.
        dades_candidat = {}
        #capturem les dades del candidat i les guardem al diccionari
        dades_candidat = obtenir_dades()
        #si la validació de les dades retorna True calculem puntuació, classifiquem candidat, mostrem puntuació i afegim a la llista de candidats.
        if validar_dades(dades_candidat):
          dades_candidat['puntuació'] = calcular_puntuació(dades_candidat)
          dades_candidat['classificació'] = classificar_candidat(dades_candidat['puntuació'])
          mostrar_individual(dades_candidat['puntuació'])
          candidats_registrats.append(dades_candidat)
          i += 1
    #mostrem informe ordenat dels candidats.
    mostrar_informe(candidats_registrats)

# %% [markdown]
# inputs_test = [
#     "Laura Serra", "608112233", 6, 3, 3, 3,
#     "Clara Gómez", "655221199", 3, 3, 3, 2,
#     "Sergio López", "644112211", 3, 2, 2, 2,
#     "Candidat Error", "611000000", 5, 7, 3, 2, # Català = 7 → NO VÀLID
#     "Marta Ruiz", "699887766", 2, 3, 2, 1,
#     "Marc Vidal", "612443322", 6, 3, 3, 3,
#     "Júlia Romero", "677998877", 5, 3, 3, 2,
#     "Pol Navarro", "699554433", 4, 3, 2, 2,
#     "David Ferrer", "677665544", 2, 1, 1, 1,
#     "Anna Paredes", "633221144", 1, 2, 1, 0,
#     "Anibal Paredes", "644272727", 1, 2, 1, 0,
#     "Núria Casals", "600112200", 8, 2, 3, 3 # 11è candidat
# ]

# %%
main_seleccio()
# Out:
# Introdueix el teu nom i cognoms: Laura Serra
# Introdueix el telèfon: 608112233
# Introdueix els anys d'experiència a l'empresa: 6
# Introdueix el nivell de coneixement de català: 3
# Introdueix el nivell de coneixement d'excel: 3
# Introdueix el tipus de títol acadèmic: 3
# La teva puntuació és 18.0
# Introdueix el teu nom i cognoms: Clara Gómez
# Introdueix el telèfon: 655221199
# Introdueix els anys d'experiència a l'empresa: 3
# Introdueix el nivell de coneixement de català: 3
# Introdueix el nivell de coneixement d'excel: 3
# Introdueix el tipus de títol acadèmic: 2
# La teva puntuació és 12.5
# Introdueix el teu nom i cognoms: Sergio Lopez
# Introdueix el telèfon: 644112211
# Introdueix els anys d'experiència a l'empresa: 3
# Introdueix el nivell de coneixement de català: 2
# Introdueix el nivell de coneixement d'excel: 2
# Introdueix el tipus de títol acadèmic: 2
# La teva puntuació és 10.5
# Introdueix el teu nom i cognoms: Candidat error
# Introdueix el telèfon: 611000000
# Introdueix els anys d'experiència a l'empresa: 5
# Introdueix el nivell de coneixement de català: 7
# Introdueix el nivell de coneixement d'excel: 3
# Introdueix el tipus de títol acadèmic: 2
# Error: El coneixement de català ha de ser entre 0 i 3.
# Introdueix el teu nom i cognoms: Marta Ruiz
# Introdueix el telèfon: 699887766
# Introdueix els anys d'experiència a l'empresa: 2
# Introdueix el nivell de coneixement de català: 3
# Introdueix el nivell de coneixement d'excel: 2
# Introdueix el tipus de títol acadèmic: 1
# La teva puntuació és 9.0
# Introdueix el teu nom i cognoms: Marc Vidal
# Introdueix el telèfon: 612443322
# Introdueix els anys d'experiència a l'empresa: 6
# Introdueix el nivell de coneixement de català: 3
# Introdueix el nivell de coneixement d'excel: 3
# Introdueix el tipus de títol acadèmic: 3
# La teva puntuació és 18.0
# Introdueix el teu nom i cognoms: 3
# Introdueix el telèfon: 677998877
# Introdueix els anys d'experiència a l'empresa: 5
# Introdueix el nivell de coneixement de català: 3
# Introdueix el nivell de coneixement d'excel: 3
# Introdueix el tipus de títol acadèmic: 2
# La teva puntuació és 15.5
# Introdueix el teu nom i cognoms: Pol Navarro
# Introdueix el telèfon: 699554433
# Introdueix els anys d'experiència a l'empresa: 4
# Introdueix el nivell de coneixement de català: 3
# Introdueix el nivell de coneixement d'excel: 2
# Introdueix el tipus de títol acadèmic: 2
# La teva puntuació és 13.0
# Introdueix el teu nom i cognoms: David Ferrer
# Introdueix el telèfon: 677665544
# Introdueix els anys d'experiència a l'empresa: 2
# Introdueix el nivell de coneixement de català: 1
# Introdueix el nivell de coneixement d'excel: 1
# Introdueix el tipus de títol acadèmic: 1
# La teva puntuació és 6.0
# Introdueix el teu nom i cognoms: Anna Paredes
# Introdueix el telèfon: 633221144
# Introdueix els anys d'experiència a l'empresa: 1
# Introdueix el nivell de coneixement de català: 2
# Introdueix el nivell de coneixement d'excel: 1
# Introdueix el tipus de títol acadèmic: 0
# La teva puntuació és 4.5
# Introdueix el teu nom i cognoms: Anibal PAredes
# Introdueix el telèfon: 644272727
# Introdueix els anys d'experiència a l'empresa: 1
# Introdueix el nivell de coneixement de català: 2
# Introdueix el nivell de coneixement d'excel: 1
# Introdueix el tipus de títol acadèmic: 0
# La teva puntuació és 4.5
# Llista de candidats:
# Laura Serra tf: 608112233 punts: 18.0
# Marc Vidal tf: 612443322 punts: 18.0
# 3 tf: 677998877 punts: 15.5
# Pol Navarro tf: 699554433 punts: 13.0
# Clara Gómez tf: 655221199 punts: 12.5
# Sergio Lopez tf: 644112211 punts: 10.5
# Marta Ruiz tf: 699887766 punts: 9.0
# David Ferrer tf: 677665544 punts: 6.0
# Anna Paredes tf: 633221144 punts: 4.5
# Anibal PAredes tf: 644272727 punts: 4.5

# %% [markdown]
# # **Exercici 2: Segmentació per risc de cistella de compra**

# %% [markdown]
# Treballes com a analista de dades al departament de Màrqueting Digital. L'empresa vol millorar l'efectivitat de les campanyes de recuperació de cistelles de compra abandonades i necessita identificar quins clients tenen més risc d'abandonament, quin segment de comportament presenten i quin missatge publicitari és el més adequat per a cadascun.

# %% [markdown]
# Disposes d'un conjunt de dades amb informació bàsica de 10 clients:
# *   id_client
# *   nom
# *   edat
# *   grup_edat
# *   codi_comportament
#
# El departament de CRM ha definit manualment:
#
# » Codis de comportament:
# *   0 → Navega però no afegeix productes
# *   1 → Afegeix productes però no arriba al checkout
# *   2 → Arriba al checkout però no paga
# *   3 → Cistella de compra abandonat fa menys de 24 h
# *   4 → Cistella de compra abandonat fa més de 24 h
#
# » Factors segons codi de comportament:
# *   Codi 0 → 0.10
# *   Codi 1 → 0.25
# *   Codi 2 → 0.50
# *   Codi 3 → 0.75
# *   Codi 4 → 0.90
#
# » Factors segons grup d'edat
# *   18–25 → 1.20
# *   26–40 → 1.00
# *   41–60 → 0.85
# *   60+ → 0.70
#
# » Fórmula del risc final
#
# risc_final = factor codi * factor edat

# %% [markdown]
# Un cop processats els clients, has de ser capaç de respondre:
# *   » 1. Quins clients s'han de contactar primer en una campanya de retargeting?
# *   » 2. Quines diferències hi ha entre clients amb el mateix comportament però d'edats diferents? (Per exemple: un client jove que abandona la cistella de compra fa 24 h té el mateix risc que un de més edat?)
# *   » 3. Quins clients presenten tan poc interès que no val la pena invertir-hi pressupost?
# *   » 4. Quin client seria el més rendible de recuperar?
#
# Interpretant el risc final i el segment.

# %% [markdown]
# Per resoldre aquest exercici, hauràs de:
#
# » Desenvolupar un sistema modular amb les funcions següents:
#
# » S'ha d'implementar amb un diccionari de diccionaris, sense condicions.
#
# processar_clients # s'ha d'alimentar de les funcions següents:
#
# obtenir_segment_i_factor
#
# obtenir_factor_edat
#
# calcular_risc
#
# mostrar_dataframe o mostrar_diccionari
#
# mostrar_respostes
#
# main_marketing # orquestra totes les funcions
#
# » Escriure primer l'algoritme pas a pas, indicant clarament quines operacions farà cada funció.
#
# » Escriure el codi de cada funció.

# %% [markdown]
# # **Resultat**

# %% [markdown]
# ## 🧠 **Algoritme inicial**
#
# 1. Processar clients:
#     *   Obtenir segment segons codi comportament.
#     *   Obtenir factor edat.
#     *   Calcular risc.
# 2. Mostrar diccionari amb les dades de tots els clients.
# 3. Mostrar respostes a les qüestions.

# %% [markdown]
# ## 🧩 **Descomponent el problema: naixement de les funcions**

# %% [markdown]
# ### ***✔ obtenir_segment_i_factor(codi de comportament)***
#
# **Paràmetre:** codi de comportament.
#
# **Tasques:**
# 1. Obtenir segment de comportament a partir del codi de comportament:
# *   0 → Navega però no afegeix productes
# *   1 → Afegeix productes però no arriba al checkout
# *   2 → Arriba al checkout però no paga
# *   3 → Cistella de compra abandonat fa menys de 24 h
# *   4 → Cistella de compra abandonat fa més de 24 h
#
# 2. Obtenir factor segons codi de comportament.
# *   Codi 0 → 0.10
# *   Codi 1 → 0.25
# *   Codi 2 → 0.50
# *   Codi 3 → 0.75
# *   Codi 4 → 0.90
#
# 3. Retornar segment, factor_codi

# %%
def obtenir_segment_i_factor(codi_comportament):
  match codi_comportament:
    case 0: segment = 'Navega però no afegeix productes'; factor = 0.10
    case 1: segment = 'Afegeix productes però no arriba al checkout'; factor = 0.25
    case 2: segment = 'Arriba al checkout però no paga'; factor = 0.50
    case 3: segment = 'Cistella de compra abandonat fa menys de 24 h'; factor = 0.75
    case 4: segment = 'Cistella de compra abandonat fa més de 24 h'; factor = 0.90
  return segment, factor

# %% [markdown]
# ### ***✔ obtenir_factor_edat(grup d'edat)***
#
# **Paràmetre:** grup d'edat
#
# **Tasques:**
#
# 1. Obtenir factor segons grup d'edat:
# *   18–25 → 1.20
# *   26–40 → 1.00
# *   41–60 → 0.85
# *   60+ → 0.70
#
# 4. Retornar factor_edat

# %%
def obtenir_factor_edat(grup_edat):
  match grup_edat:
    case '18-25': factor = 1.20
    case '26-40': factor = 1.00
    case '41-60': factor = 0.85
    case '60+': factor = 0.70
  return factor

# %% [markdown]
# ### ***✔ calcular_risc(factor codi, factor edat)***
#
# **Paràmetre:** factor codi comportament, factor edat
#
# **Tasques:**
# 1. Calcular:
# risc final = factor codi * factor edat
#
# 2. Retornar risc final

# %%
def calcular_risc(factor_codi, factor_edat):
  return factor_codi

# %% [markdown]
# ### ***✔ processar_clients(llista)***
#
# **Paràmetre:** llista de diccionaris amb les dades dels candidats.
#
# **Tasques:**
# 1. Per cada client:
#     - Obtenir segment i factor segons codi comportament.
#     - Obtenir factor edat.
#     - Calcular risc
#
# 2. Guardar aquestes dades al diccionari de cada client.

# %%
def processar_clients(llista):
  dataframe= {}
  for client in llista:
    dades_client = {}
    dades_client ['id_client'] = client['id_client']
    dades_client ['nom'] = client['nom']
    dades_client ['edat'] = client['edat']
    dades_client ['grup_edat'] = client['grup_edat']
    dades_client ['codi_comportament'] = client['codi_comportament']
    #obtenim segment i factor segons codi comportament
    dades_client ['segment'], dades_client ['factor_codi']  = obtenir_segment_i_factor(client['codi_comportament'])
    #obtenim factor segons grup d'edat
    dades_client ['factor_edat'] = obtenir_factor_edat(client['grup_edat'])
    #calculem risc
    dades_client ['risc_final'] = calcular_risc(dades_client ['factor_codi'], dades_client ['factor_edat'] )
    #afegim dades al diccionari de cada client
    dataframe[client['id_client']] = dades_client
  return dataframe

# %% [markdown]
# ### ***✔ mostrar_diccionari(llista)***
#
# **Paràmetre:** llista de diccionaris amb les dades dels candidats.
#
# **Tasques:**
# 1. Mostrar les dades de cada client

# %%
def mostrar_dataframe(dataframe):
  print ('DATAFRAME CLIENTS')
  for client in dataframe:
    print (dataframe[client])

# %% [markdown]
# ### ***✔ mostrar_respostes(llista)***
#
# **Paràmetre:** llista de diccionaris amb les dades dels candidats.
#
# **Tasques:**
# 1. Per cada client:
# *   » 1. Quins clients s'han de contactar primer en una campanya de retargeting?
# *   » 2. Quines diferències hi ha entre clients amb el mateix comportament però d'edats diferents? (Per exemple: un client jove que abandona la cistella de compra fa 24 h té el mateix risc que un de més edat?)
#
# *   » 3. Quins clients presenten tan poc interès que no val la pena invertir-hi pressupost?
# *   » 4. Quin client seria el més rendible de recuperar?
#
# 2. Guardar aquestes dades al diccionari de cada client.

# %%
def mostrar_respostes(dataframe):
  print ('RESPOSTES')

# %% [markdown]
# ### ***✔ main_marketing(llista)***
#
# **Paràmetre:** llista de diccionaris amb les dades dels candidats.
#
# **Tasques:**
# 1. Processar clients:
#     - Obtenir segment i factor segons codi comportament.
#     - Obtenir factor edat.
#     - Calcular risc
#
# 2. Mostrar diccionari.
#
# 3. Mostrar respostes.

# %%
def main_seleccio(llista_clients):
    #inicialitzem el dicconari de diccionaris on guardarem les dades de tots els clients.
    clients_segmentats = {}
    clients_segmentats = processar_clients(llista_clients)
    mostrar_dataframe(clients_segmentats)
    mostrar_respostes(clients_segmentats)

# %%
#conjunt de dades
clients = [
    {"id_client": 1, "nom": "Laura Serra", "edat": 23, "grup_edat": "18-25", "codi_comportament": 4},
    {"id_client": 2, "nom": "Marc Vidal", "edat": 35, "grup_edat": "26-40", "codi_comportament": 3},
    {"id_client": 3, "nom": "Ana López", "edat": 29, "grup_edat": "26-40", "codi_comportament": 2},
    {"id_client": 4, "nom": "Joan Riera", "edat": 19, "grup_edat": "18-25", "codi_comportament": 2},
    {"id_client": 5, "nom": "Mónica Pérez", "edat": 47, "grup_edat": "41-60", "codi_comportament": 4},
    {"id_client": 6, "nom": "Luis García", "edat": 52, "grup_edat": "41-60", "codi_comportament": 1},
    {"id_client": 7, "nom": "Pilar Sánchez", "edat": 61, "grup_edat": "60+", "codi_comportament": 3},
    {"id_client": 8, "nom": "Eva Martín", "edat": 38, "grup_edat": "26-40", "codi_comportament": 0},
    {"id_client": 9, "nom": "Diego Romero", "edat": 24, "grup_edat": "18-25", "codi_comportament": 1},
    {"id_client": 10, "nom": "Núria Costa", "edat": 33, "grup_edat": "26-40", "codi_comportament": 4}
]
main_seleccio(clients)
# Out:
# {'id_client': 1, 'nom': 'Laura Serra', 'edat': 23, 'grup_edat': '18-25', 'codi_comportament': 4, 'segment': 'Cistella de compra abandonat fa més de 24 h', 'factor_codi': 0.9, 'factor_edat': 1.2, 'risc_final': 0.9}
# {'id_client': 2, 'nom': 'Marc Vidal', 'edat': 35, 'grup_edat': '26-40', 'codi_comportament': 3, 'segment': 'Cistella de compra abandonat fa menys de 24 h', 'factor_codi': 0.75, 'factor_edat': 1.0, 'risc_final': 0.75}
# {'id_client': 3, 'nom': 'Ana López', 'edat': 29, 'grup_edat': '26-40', 'codi_comportament': 2, 'segment': 'Arriba al checkout però no paga', 'factor_codi': 0.5, 'factor_edat': 1.0, 'risc_final': 0.5}
# {'id_client': 4, 'nom': 'Joan Riera', 'edat': 19, 'grup_edat': '18-25', 'codi_comportament': 2, 'segment': 'Arriba al checkout però no paga', 'factor_codi': 0.5, 'factor_edat': 1.2, 'risc_final': 0.5}
# {'id_client': 5, 'nom': 'Mónica Pérez', 'edat': 47, 'grup_edat': '41-60', 'codi_comportament': 4, 'segment': 'Cistella de compra abandonat fa més de 24 h', 'factor_codi': 0.9, 'factor_edat': 0.85, 'risc_final': 0.9}
# {'id_client': 6, 'nom': 'Luis García', 'edat': 52, 'grup_edat': '41-60', 'codi_comportament': 1, 'segment': 'Afegeix productes però no arriba al checkout', 'factor_codi': 0.25, 'factor_edat': 0.85, 'risc_final': 0.25}
# {'id_client': 7, 'nom': 'Pilar Sánchez', 'edat': 61, 'grup_edat': '60+', 'codi_comportament': 3, 'segment': 'Cistella de compra abandonat fa menys de 24 h', 'factor_codi': 0.75, 'factor_edat': 0.7, 'risc_final': 0.75}
# {'id_client': 8, 'nom': 'Eva Martín', 'edat': 38, 'grup_edat': '26-40', 'codi_comportament': 0, 'segment': 'Navega però no afegeix productes', 'factor_codi': 0.1, 'factor_edat': 1.0, 'risc_final': 0.1}
# {'id_client': 9, 'nom': 'Diego Romero', 'edat': 24, 'grup_edat': '18-25', 'codi_comportament': 1, 'segment': 'Afegeix productes però no arriba al checkout', 'factor_codi': 0.25, 'factor_edat': 1.2, 'risc_final': 0.25}
# {'id_client': 10, 'nom': 'Núria Costa', 'edat': 33, 'grup_edat': '26-40', 'codi_comportament': 4, 'segment': 'Cistella de compra abandonat fa més de 24 h', 'factor_codi': 0.9, 'factor_edat': 1.0, 'risc_final': 0.9}
# respostes
